# %% [markdown]
# <a href="https://colab.research.google.com/github/badaniyahi/Entregable-3/blob/main/Copia_de_Copia_de_3_Respuesta_a_preguntas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U "transformers==4.40.0" --upgrade
# !pip install -i https://pypi.org/simple/ bitsandbytes
# !pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 49.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.40.0 which is incompatible.
# ...
# Looking in indexes: https://pypi.org/simple/
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 7.7 MB/s eta 0:00:00
# ...

# %%
#@title Cargando LLAMA3
import transformers
import torch

model_id = "unsloth/llama-3-8b-Instruct-bnb-4bit"

pipeline = transformers.pipeline(
    "text-generation",
    model=model_id,
    model_kwargs={
        "torch_dtype": torch.float16,
        "quantization_config": {"load_in_4bit": True},
        "low_cpu_mem_usage": True,
    },
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.26k [00:00<?, ?B/s]
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
content_url = "https://osinergmin-my.sharepoint.com/:w:/g/personal/ptaboada_osinergmin_gob_pe/EY_4sUm58KNMvUJJ8862BvoBqdk_zjBy9yxb8myJUoTZvg?e=FMtA5w"

# %%
response = requests.get(content_url)

# %%
if response.status_code == 200:
    print("La solicitud fue exitosa.")
else:
    print("Hubo un problema con la solicitud.")
# Out:
# La solicitud fue exitosa.

# %%
#@title Pregunta 1
messages = [
    {"role"   : "system",
     "content": content_url},
    {"role"   : "user",
     "content": """¿Cuál es el requisito para realizar operaciones como Consumidor Directo de Combustibles Líquidos y OPDH?"""},
]

#What points stand out about data privacy?

prompt = pipeline.tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
)

terminators = [
    pipeline.tokenizer.eos_token_id,
    pipeline.tokenizer.convert_tokens_to_ids("<|eot_id|>")
]

outputs = pipeline(
    prompt,
    max_new_tokens=256,
    eos_token_id=terminators,
    do_sample=True,
    temperature=0.6,
    top_p=0.9,
)

print(outputs[0]["generated_text"][len(prompt):])
# Out:
# Según la información proporcionada en el enlace que me proporcionaste, el requisito para realizar operaciones como Consumidor Directo de Combustibles Líquidos y OPDH es tener una autorización emitida por la Dirección General de Combustibles y Energía de la Secretaría de Energía.
#
# En particular, para ser un Consumidor Directo de Combustibles Líquidos, se requiere tener una autorización emitida por la Dirección General de Combustibles y Energía, la cual se otorga previo cumplimiento de los requisitos establecidos en el Reglamento de Combustibles Líquidos y su Resolución de Autorización.
#
# Por otro lado, para ser un OPDH (Operador de Planta de Distribución de Hidrocarburos), se requiere tener una autorización emitida por la Dirección General de Combustibles y Energía, la cual se otorga previo cumplimiento de los requisitos establecidos en el Reglamento de Operadores de Planta de Distribución de Hidrocarburos y su Resolución de Autorización.
#
# ...

# %%
#@title Pregunta 2

messages = [
    {"role": "system",
     "content": content_url},
    {"role": "user",
     "content": """¿Cuándo se realiza una suspensión de oficio?"""},
]

prompt = pipeline.tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
)

terminators = [
    pipeline.tokenizer.eos_token_id,
    pipeline.tokenizer.convert_tokens_to_ids("<|eot_id|>")
]

outputs = pipeline(
    prompt,
    max_new_tokens=256,
    eos_token_id=terminators,
    do_sample=True,
    temperature=0.6,
    top_p=0.9,
)

print(outputs[0]["generated_text"][len(prompt):])
# Out:
# Una suspensión de oficio es un procedimiento administrativo que se realiza en virtud de una ley o reglamento, y se utiliza para suspender temporalmente la ejecución de una resolución o acto administrativo, generalmente en casos en que se considera que la medida puede generar perjuicios graves o irreparables.
#
# En general, se puede realizar una suspensión de oficio en los siguientes casos:
#
# 1. Cuando se considera que la medida administrativa puede generar perjuicios graves o irreparables, y es necesario suspender su ejecución para evitar daños irreparables.
# 2. Cuando se considera que la medida administrativa es contraria a la ley o reglamento, y es necesario suspender su ejecución para evitar que se produzcan perjuicios graves o irreparables.
# 3. Cuando se considera que la medida administrativa es necesaria para proteger el interés público o el interés de una persona o grupo de personas.
#
# ...

# %%
#@title Pregunta 3
messages = [
    {"role"   : "system",
     "content": content_url},
    {"role"   : "user",
     "content": """¿Cuál es el plazo de atención de una solicitud de inscripción en el Registro de Hidrocarburos?"""},
]

prompt = pipeline.tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
)

terminators = [
    pipeline.tokenizer.eos_token_id,
    pipeline.tokenizer.convert_tokens_to_ids("<|eot_id|>")
]

outputs = pipeline(
    prompt,
    max_new_tokens=128,
    eos_token_id=terminators,
    do_sample=True,
    temperature=0.6,
    top_p=0.9,
)

print(outputs[0]["generated_text"][len(prompt):])
# Out:
# Según la información proporcionada en la página que compartiste, el plazo de atención de una solicitud de inscripción en el Registro de Hidrocarburos es de 30 días hábiles contados a partir de la fecha de presentación de la solicitud.
#
# Es importante mencionar que este plazo puede variar según la legislación y las normas específicas que rigen el Registro de Hidrocarburos en el país o región en la que se encuentre. Es recomendable verificar la información en la página oficial del Registro de Hidrocarburos o consultar con el personal
